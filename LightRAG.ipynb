# %% [markdown]
# <a href="https://colab.research.google.com/github/nvv1d/Auto-GPT/blob/master/LightRAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# Cell 1: Install Dependencies
# ============================================================
# !pip install lightrag-hku google-generativeai pypdf sentence-transformers

print("✅ Installation Complete.")
# Out:
# Collecting lightrag-hku
#   Downloading lightrag_hku-1.4.9.8-py3-none-any.whl.metadata (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Collecting pypdf
#   Downloading pypdf-6.4.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (3.13.2)
# Collecting configparser (from lightrag-hku)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (1.0.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (1.51.0)
# Collecting json_repair (from lightrag-hku)
#   Downloading json_repair-0.54.1-py3-none-any.whl.metadata (12 kB)
# Collecting nano-vectordb (from lightrag-hku)
#   Downloading nano_vectordb-0.0.4.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (2.0.2)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (2.2.2)
# Collecting pipmaster (from lightrag-hku)
#   Downloading pipmaster-1.0.10-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (2.11.10)
# Collecting pypinyin (from lightrag-hku)
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (1.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (75.2.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (8.5.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from lightrag-hku) (0.12.0)
# Collecting xlsxwriter>=3.1.0 (from lightrag-hku)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->lightrag-hku) (4.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->lightrag-hku) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->lightrag-hku) (15.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->lightrag-hku) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->lightrag-hku) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->lightrag-hku) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->lightrag-hku) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->lightrag-hku) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->lightrag-hku) (0.4.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->lightrag-hku) (1.22.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Collecting ascii_colors>=0.8.0 (from pipmaster->lightrag-hku)
#   Downloading ascii_colors-0.11.4-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->lightrag-hku) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->lightrag-hku) (1.3.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ascii_colors>=0.8.0->pipmaster->lightrag-hku) (0.2.14)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->lightrag-hku) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->lightrag-hku) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->lightrag-hku) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->lightrag-hku) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Downloading lightrag_hku-1.4.9.8-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 49.6 MB/s eta 0:00:00
# Downloading pypdf-6.4.0-py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.5/329.5 kB 12.9 MB/s eta 0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 9.1 MB/s eta 0:00:00
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Downloading json_repair-0.54.1-py3-none-any.whl (29 kB)
# Downloading nano_vectordb-0.0.4.3-py3-none-any.whl (5.6 kB)
# Downloading pipmaster-1.0.10-py3-none-any.whl (29 kB)
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 21.3 MB/s eta 0:00:00
# Downloading ascii_colors-0.11.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter, pypinyin, pypdf, nano-vectordb, json_repair, configparser, ascii_colors, pipmaster, lightrag-hku
# Successfully installed ascii_colors-0.11.4 configparser-7.2.0 json_repair-0.54.1 lightrag-hku-1.4.9.8 nano-vectordb-0.0.4.3 pipmaster-1.0.10 pypdf-6.4.0 pypinyin-0.55.0 xlsxwriter-3.2.9
# ✅ Installation Complete.

# %%
# ============================================================
# Cell 2: Mount Drive & Configure Storage
# ============================================================
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Setup Directories
WORKING_DIR = "/content/drive/MyDrive/LightRAG_Storage"
INPUT_DOCS_DIR = "/content/drive/MyDrive/Research_Papers"

if not os.path.exists(WORKING_DIR):
    os.makedirs(WORKING_DIR)
    print(f"✅ Created storage directory: {WORKING_DIR}")

if not os.path.exists(INPUT_DOCS_DIR):
    os.makedirs(INPUT_DOCS_DIR)
    print(f"⚠️  Created input directory: {INPUT_DOCS_DIR}")
    print(f"📁 Please upload your PDFs/TXT files to '{INPUT_DOCS_DIR}' in Google Drive.")
else:
    print(f"✅ Storage connected. Reading papers from: {INPUT_DOCS_DIR}")
# Out:
# Mounted at /content/drive
# ✅ Storage connected. Reading papers from: /content/drive/MyDrive/Research_Papers

# %%
# ============================================================
# Cell 3: Configure LOCAL Models (No API needed!)
# ============================================================
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from sentence_transformers import SentenceTransformer
from lightrag import LightRAG, QueryParam
from lightrag.utils import EmbeddingFunc
from lightrag.llm.hf import hf_model_complete
import numpy as np

print("🧹 Clearing GPU memory...")
torch.cuda.empty_cache()

# Model Selection - Choose based on your needs:

# OPTION 1: Qwen2.5-3B (RECOMMENDED - Best balance)
LLM_MODEL = "Qwen/Qwen2.5-3B-Instruct"  # ~4GB GPU, good quality

# OPTION 2: Qwen2.5-1.5B (Fastest, lighter)
# LLM_MODEL = "Qwen/Qwen2.5-1.5B-Instruct"  # ~2GB GPU, acceptable quality

# OPTION 3: Qwen2.5-7B (Best quality, needs more memory)
# LLM_MODEL = "Qwen/Qwen2.5-7B-Instruct"  # ~8-9GB GPU, best quality

EMBEDDING_MODEL = "sentence-transformers/all-MiniLM-L6-v2"

print(f"⏳ Loading LLM: {LLM_MODEL}")
print("   (This takes 2-3 minutes on first run...)")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(LLM_MODEL)

# Load embedding model
print(f"⏳ Loading embedding model: {EMBEDDING_MODEL}")
embed_model = SentenceTransformer(EMBEDDING_MODEL)

print("✅ Models loaded!")

# Custom embedding function for SentenceTransformer
async def local_embed(texts):
    """Async wrapper for SentenceTransformer embedding"""
    import asyncio
    loop = asyncio.get_event_loop()
    embeddings = await loop.run_in_executor(
        None,
        lambda: embed_model.encode(texts, convert_to_numpy=True, show_progress_bar=False)
    )
    return embeddings

# Initialize LightRAG with local models
print("⏳ Initializing LightRAG...")
rag = LightRAG(
    working_dir=WORKING_DIR,
    llm_model_func=hf_model_complete,
    llm_model_name=LLM_MODEL,
    llm_model_max_async=1,  # Single worker for stability
    llm_model_kwargs={
        "device_map": "auto",
        "torch_dtype": torch.float16,  # Use float16 without quantization
        "max_new_tokens": 512,
        "do_sample": False,  # Deterministic output
    },
    embedding_func=EmbeddingFunc(
        embedding_dim=384,
        max_token_size=512,
        func=local_embed  # Use our custom async wrapper
    ),
    # Optimized settings for smaller model
    chunk_token_size=800,
    chunk_overlap_token_size=100,
    entity_extract_max_gleaning=0,  # Skip refinement for speed
)

# Initialize storage
from lightrag.kg.shared_storage import initialize_pipeline_status

await rag.initialize_storages()
await initialize_pipeline_status()

print("\n" + "="*60)
print("✅ LightRAG System Online!")
print("="*60)
print(f"🖥️  LLM: {LLM_MODEL} (float16)")
print(f"🖥️  Embeddings: {EMBEDDING_MODEL} (local)")
print(f"💾 GPU Memory: ~{torch.cuda.memory_allocated()/1024**3:.1f}GB / 15GB")
print(f"⚡ All processing runs locally - no API limits!")
print("="*60)
# Out:
# 🧹 Clearing GPU memory...
# ⏳ Loading LLM: Qwen/Qwen2.5-3B-Instruct
#    (This takes 2-3 minutes on first run...)
# ⏳ Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# INFO: [_] Loaded graph from /content/drive/MyDrive/LightRAG_Storage/graph_chunk_entity_relation.graphml with 0 nodes, 0 edges
# ✅ Models loaded!
# ⏳ Initializing LightRAG...
#
# ============================================================
# ✅ LightRAG System Online!
# ============================================================
# 🖥️  LLM: Qwen/Qwen2.5-3B-Instruct (float16)
# 🖥️  Embeddings: sentence-transformers/all-MiniLM-L6-v2 (local)
# 💾 GPU Memory: ~0.2GB / 15GB
# ⚡ All processing runs locally - no API limits!
# ============================================================

# %%
# ============================================================
# Cell 4: Index Documents
# ============================================================
import glob
from pypdf import PdfReader

async def index_papers():
    """Index all documents in the INPUT_DOCS_DIR"""
    files = glob.glob(f"{INPUT_DOCS_DIR}/*.txt") + \
            glob.glob(f"{INPUT_DOCS_DIR}/*.pdf")

    if not files:
        print("❌ No files found! Please upload PDFs or TXT files to:")
        print(f"   {INPUT_DOCS_DIR}")
        return

    print(f"📚 Found {len(files)} documents")
    indexed_count = 0

    for idx, file_path in enumerate(files, 1):
        file_name = os.path.basename(file_path)
        print(f"[{idx}/{len(files)}] Processing: {file_name}...")

        try:
            content = ""
            if file_path.endswith(".pdf"):
                reader = PdfReader(file_path)
                for page in reader.pages:
                    text = page.extract_text()
                    if text:
                        content += text + "\n"
            else:
                with open(file_path, "r", encoding="utf-8", errors='ignore') as f:
                    content = f.read()

            if len(content) > 100:
                await rag.ainsert(content)
                indexed_count += 1
                print(f"  ✅ Indexed successfully")
            else:
                print(f"  ⚠️  Skipped (content too short)")

        except Exception as e:
            print(f"  ❌ Error: {e}")

    print(f"\n🎉 Indexing Complete! Processed {indexed_count}/{len(files)} documents")
    print(f"💾 Knowledge graph saved to: {WORKING_DIR}")

# Run indexing
# NOTE: Only run this cell when you add new documents!
await index_papers()
# Out:
# WARNING: Ignoring document ID (already exists): doc-14988456e477bf51ec3488b3f381162d (unknown_source)
# WARNING: No new unique documents were found.
# INFO: Reset 1 documents from PROCESSING/FAILED to PENDING status
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: unknown_source
# INFO: Processing d-id: doc-14988456e477bf51ec3488b3f381162d
# INFO: Embedding func: 8 new workers initialized (Timeouts: Func: 30s, Worker: 60s, Health Check: 75s)
# 📚 Found 1 documents
# [1/1] Processing: Zotero Report.txt...
# INFO: LLM func: 1 new workers initialized (Timeouts: Func: 180s, Worker: 360s, Health Check: 375s)
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# INFO:  == LLM cache == saving: default:extract:b94159f4994399ba99c570e6540cd095
# WARNING: chunk-00850b1c3f948a71fe7f1406ac0db5d6: Complete delimiter can not be found in extraction result
# WARNING: chunk-00850b1c3f948a71fe7f1406ac0db5d6: LLM output format error; found 3/4 feilds on ENTITY `Sixty-Four Studies` @ `data`
# INFO: Chunk 1 of 112 extracted 12 Ent + 0 Rel chunk-00850b1c3f948a71fe7f1406ac0db5d6
# INFO:  == LLM cache == saving: default:extract:0aac8c60f3c1f2b33813f5044e24b7bb
# WARNING: chunk-af514b5d5341cdd0373165f94c8d3a4f: Complete delimiter can not be found in extraction result
# INFO: Chunk 2 of 112 extracted 13 Ent + 0 Rel chunk-af514b5d5341cdd0373165f94c8d3a4f
# INFO:  == LLM cache == saving: default:extract:e6ab3c4333bd423f00370235afb8ac0e
# WARNING: chunk-986b7fc234e23ccfce54b963e5970244: Complete delimiter can not be found in extraction result
# INFO: Chunk 3 of 112 extracted 15 Ent + 0 Rel chunk-986b7fc234e23ccfce54b963e5970244
# INFO:  == LLM cache == saving: default:extract:831b4dd4253daa62bd0ad0ffbfeb8a97
# WARNING: chunk-4782431d811de9324468ef1fed60cb77: Complete delimiter can not be found in extraction result
# WARNING: chunk-4782431d811de9324468ef1fed60cb77: LLM output format error; found 2/4 feilds on ENTITY `DOI 10.1017/S0958344023000` @ `N/A`
# INFO: Chunk 4 of 112 extracted 11 Ent + 0 Rel chunk-4782431d811de9324468ef1fed60cb77
# INFO:  == LLM cache == saving: default:extract:4202cd1677d7b0d348e1aacba52a0d43
# WARNING: chunk-e66c943b1316f01e4e911c380dc25fd0: Complete delimiter can not be found in extraction result
# WARNING: chunk-e66c943b1316f01e4e911c380dc25fd0: LLM output format error; found 2/5 fields on REALTION `ACS-`~`N/A`
# INFO: Chunk 5 of 112 extracted 8 Ent + 4 Rel chunk-e66c943b1316f01e4e911c380dc25fd0
# INFO:  == LLM cache == saving: default:extract:eaab979711c67097c2f599ace63cb945
# WARNING: chunk-8ac6cf85e8e0cac118fa0eec5ade8928: Complete delimiter can not be found in extraction result
# INFO: Chunk 6 of 112 extracted 13 Ent + 0 Rel chunk-8ac6cf85e8e0cac118fa0eec5ade8928
# INFO:  == LLM cache == saving: default:extract:a71c4b47feae61f2b7c107fb22e7e34a
# WARNING: chunk-ac629a205c51d4d989d6a6ade8e56466: Complete delimiter can not be found in extraction result
# INFO: Chunk 7 of 112 extracted 10 Ent + 4 Rel chunk-ac629a205c51d4d989d6a6ade8e56466
# INFO:  == LLM cache == saving: default:extract:33901bc4e66de16cb73655a202f9423f
# WARNING: chunk-78cc98dd649177f0267bcad14e94916e: Complete delimiter can not be found in extraction result
# INFO: Chunk 8 of 112 extracted 13 Ent + 0 Rel chunk-78cc98dd649177f0267bcad14e94916e
# INFO:  == LLM cache == saving: default:extract:490281e74e14d4f47b6207af4f362009
# WARNING: chunk-c3dc653e88f432297447015fac4ec6a4: Complete delimiter can not be found in extraction result
# INFO: Chunk 9 of 112 extracted 13 Ent + 0 Rel chunk-c3dc653e88f432297447015fac4ec6a4
# INFO:  == LLM cache == saving: default:extract:16a4aa5d501ad9505a1f2bb3297c9c7d
# WARNING: chunk-e390f8d37c04ce08963639d166df9fe6: Complete delimiter can not be found in extraction result
# INFO: Chunk 10 of 112 extracted 9 Ent + 0 Rel chunk-e390f8d37c04ce08963639d166df9fe6
# INFO:  == LLM cache == saving: default:extract:5835c8358ee056ce20750e064f435db0
# WARNING: chunk-65019547b17eee7fa5b5b7317a8b62a2: Complete delimiter can not be found in extraction result
# INFO: Chunk 11 of 112 extracted 13 Ent + 2 Rel chunk-65019547b17eee7fa5b5b7317a8b62a2
# INFO:  == LLM cache == saving: default:extract:fb063fce8390eb6d61f50414d233bd13
# WARNING: chunk-ad9c0c2c19b85e48accfeb4866e06e3c: Complete delimiter can not be found in extraction result
# WARNING: chunk-ad9c0c2c19b85e48accfeb4866e06e3c: LLM output format error; found 2/4 feilds on ENTITY `AI` @ `N/A`
# INFO: Chunk 12 of 112 extracted 14 Ent + 0 Rel chunk-ad9c0c2c19b85e48accfeb4866e06e3c
# INFO:  == LLM cache == saving: default:extract:224d7ffe28ef29c9dbdc00d68f96c60f
# WARNING: chunk-636d0be7237c0a90203888952e9bb167: Complete delimiter can not be found in extraction result
# WARNING: chunk-636d0be7237c0a90203888952e9bb167: LLM output format error; found 2/4 feilds on ENTITY `Mixed-method` @ `N/A`
# INFO: Chunk 13 of 112 extracted 13 Ent + 0 Rel chunk-636d0be7237c0a90203888952e9bb167
# INFO:  == LLM cache == saving: default:extract:7884dbe0e57d82dd2bfe998b58621ffd
# WARNING: chunk-9db3ff42316dbd88965f281688ac9d88: Complete delimiter can not be found in extraction result
# INFO: Chunk 14 of 112 extracted 17 Ent + 0 Rel chunk-9db3ff42316dbd88965f281688ac9d88
# INFO:  == LLM cache == saving: default:extract:860ae78ca93fcec2cc1d1307344dac2b
# WARNING: chunk-73e81884b25dda4385484bc465b8fd8f: Complete delimiter can not be found in extraction result
# WARNING: chunk-73e81884b25dda4385484bc465b8fd8f: LLM output format error; found 2/4 feilds on ENTITY `Vocabulary` @ `N/A`
# INFO: Chunk 15 of 112 extracted 15 Ent + 0 Rel chunk-73e81884b25dda4385484bc465b8fd8f
# INFO:  == LLM cache == saving: default:extract:39e865f796655d3615b1728cccb5efc7
# WARNING: chunk-8bfcd5e016973b236fd04b6ad5738980: Complete delimiter can not be found in extraction result
# WARNING: chunk-8bfcd5e016973b236fd04b6ad5738980: LLM output format error; found 2/4 feilds on ENTITY `Artificial Intelligence` @ `N/A`
# INFO: Chunk 16 of 112 extracted 12 Ent + 0 Rel chunk-8bfcd5e016973b236fd04b6ad5738980
# INFO:  == LLM cache == saving: default:extract:af118e09f32f3d5187f5b24bb6f640e3
# WARNING: chunk-b24cc962542348d77484f4617675f659: Complete delimiter can not be found in extraction result
# INFO: Chunk 17 of 112 extracted 14 Ent + 0 Rel chunk-b24cc962542348d77484f4617675f659
# INFO:  == LLM cache == saving: default:extract:b47223990cda945042022dacc5673b03
# WARNING: chunk-aacc533b3309ab4a67f91a7d5246f5f9: Complete delimiter can not be found in extraction result
# INFO: Chunk 18 of 112 extracted 14 Ent + 0 Rel chunk-aacc533b3309ab4a67f91a7d5246f5f9
# INFO:  == LLM cache == saving: default:extract:ad05195fdf17b90acf45b4bf9911fde4
# WARNING: chunk-8f0201401b169f03793d6a3e97cad65d: Complete delimiter can not be found in extraction result
# WARNING: chunk-8f0201401b169f03793d6a3e97cad65d: LLM output format error; found 2/4 feilds on ENTITY `L2 Student Writers` @ `N/A`
# INFO: Chunk 19 of 112 extracted 14 Ent + 0 Rel chunk-8f0201401b169f03793d6a3e97cad65d
# INFO:  == LLM cache == saving: default:extract:498e2afc9825cd8e8f542e30505f2598
# WARNING: chunk-c4db473297ec6ccbf0768312ae5831e0: Complete delimiter can not be found in extraction result
# WARNING: chunk-c4db473297ec6ccbf0768312ae5831e0: LLM output format error; found 2/4 feilds on ENTITY `Experimental Group<` @ `N/A`
# INFO: Chunk 20 of 112 extracted 13 Ent + 0 Rel chunk-c4db473297ec6ccbf0768312ae5831e0
# INFO:  == LLM cache == saving: default:extract:169c633a03fcb375913a0a67dabc1932
# WARNING: chunk-b42fd12785c0fc74024f65a2522ac71d: Complete delimiter can not be found in extraction result
# WARNING: chunk-b42fd12785c0fc74024f65a2522ac71d: LLM output format error; found 3/4 feilds on ENTITY `Co-regulated Learning` @ `concept`
# INFO: Chunk 21 of 112 extracted 12 Ent + 0 Rel chunk-b42fd12785c0fc74024f65a2522ac71d
# INFO:  == LLM cache == saving: default:extract:33cb2a85dec23dca24afd8027e5fc746
# WARNING: chunk-518f937727807ebfed95ac517b0890cb: Complete delimiter can not be found in extraction result
# INFO: Chunk 22 of 112 extracted 14 Ent + 0 Rel chunk-518f937727807ebfed95ac517b0890cb
# INFO:  == LLM cache == saving: default:extract:835052558c65feda0082fcf74233eb51
# WARNING: chunk-d2aa816bfac643364e4143fb84bf881d: Complete delimiter can not be found in extraction result
# INFO: Chunk 23 of 112 extracted 5 Ent + 7 Rel chunk-d2aa816bfac643364e4143fb84bf881d
# INFO:  == LLM cache == saving: default:extract:6ace32a5b117cc6014fd59dc3ca9a458
# WARNING: chunk-0e83de4e002459f613a0fa326e735ef2: Complete delimiter can not be found in extraction result
# WARNING: chunk-0e83de4e002459f613a0fa326e735ef2: LLM output format error; found 2/4 feilds on ENTITY `Engagement<|#` @ `N/A`
# INFO: Chunk 24 of 112 extracted 18 Ent + 0 Rel chunk-0e83de4e002459f613a0fa326e735ef2
# INFO:  == LLM cache == saving: default:extract:39f5034ffe1ec417f447b7202c145359
# WARNING: chunk-9aa4db494bc8d4fff64de61da1eba61f: Complete delimiter can not be found in extraction result
# INFO: Chunk 25 of 112 extracted 16 Ent + 0 Rel chunk-9aa4db494bc8d4fff64de61da1eba61f
# INFO:  == LLM cache == saving: default:extract:3cbac99c04eb9d16e8295d275dc2f04e
# WARNING: chunk-0d2f9a388de365532047eefbe1ce0699: Complete delimiter can not be found in extraction result
# INFO: Chunk 26 of 112 extracted 13 Ent + 0 Rel chunk-0d2f9a388de365532047eefbe1ce0699
# INFO:  == LLM cache == saving: default:extract:50b515fb2fe1cecc399f3e175c0427b1
# WARNING: chunk-9ba5166fb0ab1ba7d64f90e9971ad285: Complete delimiter can not be found in extraction result
# WARNING: chunk-9ba5166fb0ab1ba7d64f90e9971ad285: LLM output format error; found 4/5 fields on REALTION `Scott Aubrey`~`International Journal of Applied Linguistics`
# INFO: Chunk 27 of 112 extracted 8 Ent + 3 Rel chunk-9ba5166fb0ab1ba7d64f90e9971ad285
# INFO:  == LLM cache == saving: default:extract:c3a6edeba36ec8de9744ae11f24dcafd
# WARNING: chunk-738446c6b228cad1fc7a4c1f3f5a6839: Complete delimiter can not be found in extraction result
# INFO: Chunk 28 of 112 extracted 15 Ent + 0 Rel chunk-738446c6b228cad1fc7a4c1f3f5a6839
# INFO:  == LLM cache == saving: default:extract:71d3198c44677ef47f08f6b7bcabf5c0
# WARNING: chunk-e83bf05e1e5e5bd88be5bbf6928fb57e: Complete delimiter can not be found in extraction result
# INFO: Chunk 29 of 112 extracted 14 Ent + 0 Rel chunk-e83bf05e1e5e5bd88be5bbf6928fb57e
# INFO:  == LLM cache == saving: default:extract:6d88d20d9e95c7225b5abae73358715f
# WARNING: chunk-ecbd315acaaa65cf37cef4f4c6b0e448: Complete delimiter can not be found in extraction result
# INFO: Chunk 30 of 112 extracted 11 Ent + 0 Rel chunk-ecbd315acaaa65cf37cef4f4c6b0e448
# INFO:  == LLM cache == saving: default:extract:96eb2fdc2f88388d7408ef26f048bb4f
# WARNING: chunk-bbbf33a20cca5c6a407f61dea45b7c24: Complete delimiter can not be found in extraction result
# INFO: Chunk 31 of 112 extracted 15 Ent + 0 Rel chunk-bbbf33a20cca5c6a407f61dea45b7c24
# INFO:  == LLM cache == saving: default:extract:7e761e1fc0f6bf4533d98d8ef1f08a36
# WARNING: chunk-008897c5cf668645d59c116120a8b07d: Complete delimiter can not be found in extraction result
# WARNING: chunk-008897c5cf668645d59c116120a8b07d: LLM output format error; found 2/4 feilds on ENTITY `Automated Writing Evaluation System<|#` @ `N/A`
# INFO: Chunk 32 of 112 extracted 15 Ent + 0 Rel chunk-008897c5cf668645d59c116120a8b07d
# INFO:  == LLM cache == saving: default:extract:49b268931ca029fef73a37cf989430c7
# WARNING: chunk-636836af983328839f7b70419caca831: Complete delimiter can not be found in extraction result
# INFO: Chunk 33 of 112 extracted 16 Ent + 0 Rel chunk-636836af983328839f7b70419caca831
# INFO:  == LLM cache == saving: default:extract:14dc5f35f66e87f8f49bc67f12435781
# WARNING: chunk-45e2bc3f347fe413466c13614d19f572: Complete delimiter can not be found in extraction result
# WARNING: chunk-45e2bc3f347fe413466c13614d19f572: LLM output format error; found 4/5 fields on REALTION `Hamed Mohammad Hosseini`~`Ali Derakhshesh`
# INFO: Chunk 34 of 112 extracted 13 Ent + 0 Rel chunk-45e2bc3f347fe413466c13614d19f572
# INFO:  == LLM cache == saving: default:extract:2241f41f46de72f4f197827c403f0424
# WARNING: chunk-1710a63a4c8303cdaf191db63c570191: Complete delimiter can not be found in extraction result
# INFO: Chunk 35 of 112 extracted 15 Ent + 0 Rel chunk-1710a63a4c8303cdaf191db63c570191
# INFO:  == LLM cache == saving: default:extract:941fa6956c0e7a939ab4b38eb4a66027
# WARNING: chunk-b2478be8965aab9bc6275e27aa63e138: Complete delimiter can not be found in extraction result
# INFO: Chunk 36 of 112 extracted 14 Ent + 0 Rel chunk-b2478be8965aab9bc6275e27aa63e138
# INFO:  == LLM cache == saving: default:extract:b72f88d81dc3feb196b1475c3ee2e6cb
# WARNING: chunk-7f1075e49b7aa175df9d6c853d39d1ab: Complete delimiter can not be found in extraction result
# INFO: Chunk 37 of 112 extracted 16 Ent + 0 Rel chunk-7f1075e49b7aa175df9d6c853d39d1ab
# INFO:  == LLM cache == saving: default:extract:14d1cb5ebdc57e9bfbfdc6bd6f7e2c70
# WARNING: chunk-1fccdb7299c1b61a2b13d16ef710ef03: Complete delimiter can not be found in extraction result
# INFO: Chunk 38 of 112 extracted 14 Ent + 0 Rel chunk-1fccdb7299c1b61a2b13d16ef710ef03
# INFO:  == LLM cache == saving: default:extract:bcaa66a0d3fb8d2be82fc8155cff6685
# WARNING: chunk-c0fa2d9c7916ed1b176ce74d91149f03: Complete delimiter can not be found in extraction result
# INFO: Chunk 39 of 112 extracted 14 Ent + 0 Rel chunk-c0fa2d9c7916ed1b176ce74d91149f03
# INFO:  == LLM cache == saving: default:extract:c9c5c72b9864b49b55a7b3b121f90253
# WARNING: chunk-c0120895be7511c847e76263454a3552: Complete delimiter can not be found in extraction result
# INFO: Chunk 40 of 112 extracted 10 Ent + 0 Rel chunk-c0120895be7511c847e76263454a3552
# INFO:  == LLM cache == saving: default:extract:290c3aab2d419c13914df1736e98e817
# WARNING: chunk-3062021bdeb6f0e5ed1bfcbe7f7419a9: Complete delimiter can not be found in extraction result
# INFO: Chunk 41 of 112 extracted 14 Ent + 0 Rel chunk-3062021bdeb6f0e5ed1bfcbe7f7419a9
# INFO:  == LLM cache == saving: default:extract:7aff9d3ec057ac7b4ca4798561f75018
# WARNING: chunk-87da634e2acd5e276d09bac9dc4cab04: Complete delimiter can not be found in extraction result
# WARNING: chunk-87da634e2acd5e276d09bac9dc4cab04: LLM output format error; found 3/4 feilds on ENTITY `Plagiarism` @ `concept<`
# INFO: Chunk 42 of 112 extracted 13 Ent + 0 Rel chunk-87da634e2acd5e276d09bac9dc4cab04
# INFO:  == LLM cache == saving: default:extract:deb964163b766c492a7f60c8c5d84005
# WARNING: chunk-ccb4d4ea4b3138b6fea94853012d60c1: Complete delimiter can not be found in extraction result
# WARNING: chunk-ccb4d4ea4b3138b6fea94853012d60c1: LLM output format error; found 2/4 feilds on ENTITY `Gener` @ `N/A`
# INFO: Chunk 43 of 112 extracted 14 Ent + 0 Rel chunk-ccb4d4ea4b3138b6fea94853012d60c1
# INFO:  == LLM cache == saving: default:extract:d3fae9e45308ac1753fd61204458c0ab
# WARNING: chunk-ad97c7631aa3bc38423eca191e17bd19: Complete delimiter can not be found in extraction result
# WARNING: chunk-ad97c7631aa3bc38423eca191e17bd19: LLM output format error; found 2/4 feilds on ENTITY `Linguistic Knowledge` @ `N/A`
# INFO: Chunk 44 of 112 extracted 12 Ent + 0 Rel chunk-ad97c7631aa3bc38423eca191e17bd19
# INFO:  == LLM cache == saving: default:extract:7d2a3f6de506c5d7e72661024b5b45e6
# WARNING: chunk-30d0bca23824d38a59ea7972593171d7: Complete delimiter can not be found in extraction result
# WARNING: chunk-30d0bca23824d38a59ea7972593171d7: LLM output format error; found 2/5 fields on REALTION `Temirbolat Kenshinbay`~`N/A`
# INFO: Chunk 45 of 112 extracted 13 Ent + 0 Rel chunk-30d0bca23824d38a59ea7972593171d7
# INFO:  == LLM cache == saving: default:extract:b1aaf8e931e77dce1d3dcffca199a252
# WARNING: chunk-e20abf622ba7c6e2a8602dd77fa8c42b: Complete delimiter can not be found in extraction result
# INFO: Chunk 46 of 112 extracted 9 Ent + 2 Rel chunk-e20abf622ba7c6e2a8602dd77fa8c42b
# INFO:  == LLM cache == saving: default:extract:162474a8be4f03f3497d89160e853600
# WARNING: chunk-73a635bfd161b714617d6cf211a8fe0c: Complete delimiter can not be found in extraction result
# WARNING: chunk-73a635bfd161b714617d6cf211a8fe0c: LLM output format error; found 3/4 feilds on ENTITY `ERNIE Bot` @ `artifact`
# INFO: Chunk 47 of 112 extracted 12 Ent + 0 Rel chunk-73a635bfd161b714617d6cf211a8fe0c
# INFO:  == LLM cache == saving: default:extract:993041b313559f098e7e57c2ca572e50
# WARNING: chunk-2b6f33cf4eb23202f0672b4bd1b568f0: Complete delimiter can not be found in extraction result
# WARNING: chunk-2b6f33cf4eb23202f0672b4bd1b568f0: LLM output format error; found 2/4 feilds on ENTITY `Emotional Ex` @ `N/A`
# INFO: Chunk 48 of 112 extracted 12 Ent + 0 Rel chunk-2b6f33cf4eb23202f0672b4bd1b568f0
# INFO:  == LLM cache == saving: default:extract:8cd2affdc69b4438891afe3d14f7283b
# WARNING: chunk-1fa451e97a79af29b862a9c48d3f628e: Complete delimiter can not be found in extraction result
# WARNING: chunk-1fa451e97a79af29b862a9c48d3f628e: LLM output format error; found 2/4 feilds on ENTITY `Blended Learning Approach` @ `N/A`
# INFO: Chunk 49 of 112 extracted 14 Ent + 0 Rel chunk-1fa451e97a79af29b862a9c48d3f628e
# INFO:  == LLM cache == saving: default:extract:a60d6562eed1560ecd0f39d05a85305b
# WARNING: chunk-fe6a344099ad0f6c2812e49f0b90ae36: Complete delimiter can not be found in extraction result
# INFO: Chunk 50 of 112 extracted 14 Ent + 0 Rel chunk-fe6a344099ad0f6c2812e49f0b90ae36
# INFO:  == LLM cache == saving: default:extract:4eb087f269628c95aad76fa70b939e88
# WARNING: chunk-bc71fd4dc39e97e58162457fe1a0552c: Complete delimiter can not be found in extraction result
# WARNING: chunk-bc71fd4dc39e97e58162457fe1a0552c: LLM output format error; found 3/4 feilds on ENTITY `One-Way ANCOVA` @ `method`
# INFO: Chunk 51 of 112 extracted 14 Ent + 0 Rel chunk-bc71fd4dc39e97e58162457fe1a0552c
# INFO:  == LLM cache == saving: default:extract:dbe7cdc33d04711f180e938258f8f8d0
# WARNING: chunk-9d21fd81be59ca14ab84896b362a03a4: Complete delimiter can not be found in extraction result
# INFO: Chunk 52 of 112 extracted 14 Ent + 0 Rel chunk-9d21fd81be59ca14ab84896b362a03a4
# INFO:  == LLM cache == saving: default:extract:1fb7ec773ab4807f88fa5d3a1bc839ba
# WARNING: chunk-996960a3264fb808334eb3ca79f9127f: Complete delimiter can not be found in extraction result
# INFO: Chunk 53 of 112 extracted 12 Ent + 1 Rel chunk-996960a3264fb808334eb3ca79f9127f
# INFO:  == LLM cache == saving: default:extract:5d0aac97400aff91d92b0107f5543908
# WARNING: chunk-f9e13fd3192c9b95a3b61c7662c5f938: Complete delimiter can not be found in extraction result
# WARNING: chunk-f9e13fd3192c9b95a3b61c7662c5f938: LLM output format error; found 2/4 feilds on ENTITY `Language Teaching Research` @ `N/A`
# INFO: Chunk 54 of 112 extracted 11 Ent + 0 Rel chunk-f9e13fd3192c9b95a3b61c7662c5f938
# INFO:  == LLM cache == saving: default:extract:4f54e139441dc93fe326332844375587
# WARNING: chunk-234e401ea1b2d14ec23c759c0199525f: Complete delimiter can not be found in extraction result
# WARNING: chunk-234e401ea1b2d14ec23c759c0199525f: LLM output format error; found 2/5 fields on REALTION `Hal E`~`N/A`
# INFO: Chunk 55 of 112 extracted 14 Ent + 0 Rel chunk-234e401ea1b2d14ec23c759c0199525f
# INFO:  == LLM cache == saving: default:extract:ee98e248c8ed581af9b6e98bd0b3281b
# WARNING: chunk-7099e834b3ce685949e3c93a8adaadee: Complete delimiter can not be found in extraction result
# INFO: Chunk 56 of 112 extracted 14 Ent + 0 Rel chunk-7099e834b3ce685949e3c93a8adaadee
# INFO:  == LLM cache == saving: default:extract:542774bdda077082d4bfb1f6d092a63c
# WARNING: chunk-76cba0d252697658fcd6f0ff29321c5c: Complete delimiter can not be found in extraction result
# INFO: Chunk 57 of 112 extracted 14 Ent + 0 Rel chunk-76cba0d252697658fcd6f0ff29321c5c
# INFO:  == LLM cache == saving: default:extract:5426cee02531e4ec05204395b344661a
# WARNING: chunk-4b8a1653d7c4c73e9363acb83391b885: Complete delimiter can not be found in extraction result
# INFO: Chunk 58 of 112 extracted 7 Ent + 0 Rel chunk-4b8a1653d7c4c73e9363acb83391b885
# INFO:  == LLM cache == saving: default:extract:c99a6617b65ca0fd2fd4caeae7fdfc9f
# WARNING: chunk-dafc3ba45226bfde3780b58d4b4c84ee: Complete delimiter can not be found in extraction result
# WARNING: chunk-dafc3ba45226bfde3780b58d4b4c84ee: LLM output format error; found 3/5 fields on REALTION `Van, Türkiye`~`Inter`
# INFO: Chunk 59 of 112 extracted 5 Ent + 5 Rel chunk-dafc3ba45226bfde3780b58d4b4c84ee
# INFO:  == LLM cache == saving: default:extract:fa0bd9556dcc99d7bffed264748721d9
# WARNING: chunk-7b7490adedcdf6e27c228f0ffe480171: Complete delimiter can not be found in extraction result
# INFO: Chunk 60 of 112 extracted 11 Ent + 0 Rel chunk-7b7490adedcdf6e27c228f0ffe480171
# INFO:  == LLM cache == saving: default:extract:a0157b8b9edd1cbd16d999a666aac9c3
# WARNING: chunk-3d88793d00c4ad98b1d40fbf32eef947: Complete delimiter can not be found in extraction result
# INFO: Chunk 61 of 112 extracted 14 Ent + 0 Rel chunk-3d88793d00c4ad98b1d40fbf32eef947
# INFO:  == LLM cache == saving: default:extract:579610f43ee098384d0462869db52be3
# WARNING: chunk-0aaccb575a8644c873b3d57df3144517: Complete delimiter can not be found in extraction result
# WARNING: chunk-0aaccb575a8644c873b3d57df3144517: LLM output format error; found 4/5 fields on REALTION `Ali Derakhshesh`~`Ideal L2 Writing Self`
# INFO: Chunk 62 of 112 extracted 5 Ent + 3 Rel chunk-0aaccb575a8644c873b3d57df3144517
# INFO:  == LLM cache == saving: default:extract:97a4dd84c6b1d8f08ab16233c2527edd
# WARNING: chunk-a42b844675fef2fff33cad56b2067efb: Complete delimiter can not be found in extraction result
# INFO: Chunk 63 of 112 extracted 10 Ent + 1 Rel chunk-a42b844675fef2fff33cad56b2067efb
# INFO:  == LLM cache == saving: default:extract:22f929bcc38ec7b8781afd3a837cb9be
# WARNING: chunk-77ba5d1f292f3ecde0fc5be3fd05a5b3: Complete delimiter can not be found in extraction result
# WARNING: chunk-77ba5d1f292f3ecde0fc5be3fd05a5b3: LLM output format error; found 2/4 feilds on ENTITY `L2 Writing Achievement` @ `N/A`
# INFO: Chunk 64 of 112 extracted 13 Ent + 0 Rel chunk-77ba5d1f292f3ecde0fc5be3fd05a5b3
# INFO:  == LLM cache == saving: default:extract:6a9568b03996d620cc9765abe67b1c12
# WARNING: chunk-1d14e56cba9c07723c48656095c514fa: Complete delimiter can not be found in extraction result
# INFO: Chunk 65 of 112 extracted 17 Ent + 0 Rel chunk-1d14e56cba9c07723c48656095c514fa
# INFO:  == LLM cache == saving: default:extract:ad434f515ffba59213341a513865ea07
# WARNING: chunk-fcfeffe2d0a48f7a3378fdf2a489e4f1: Complete delimiter can not be found in extraction result
# INFO: Chunk 66 of 112 extracted 10 Ent + 0 Rel chunk-fcfeffe2d0a48f7a3378fdf2a489e4f1
# INFO:  == LLM cache == saving: default:extract:0838e9d96820125ffb0dd9ccd724bac8
# WARNING: chunk-c33b0b415d7f45b064cddd701f7e2258: Complete delimiter can not be found in extraction result
# WARNING: chunk-c33b0b415d7f45b064cddd701f7e2258: LLM output format error; found 3/4 feilds on ENTITY `Argumentation` @ `concept`
# INFO: Chunk 67 of 112 extracted 14 Ent + 0 Rel chunk-c33b0b415d7f45b064cddd701f7e2258
# INFO:  == LLM cache == saving: default:extract:ad16fe1ceb656a54177767d5ccb3c80c
# WARNING: chunk-4ea618890f71d27e2096399bad6cd1de: Complete delimiter can not be found in extraction result
# WARNING: chunk-4ea618890f71d27e2096399bad6cd1de: LLM output format error; found 3/4 feilds on ENTITY `Akaike Information Criterion Corrected (AICC)` @ `method<`
# INFO: Chunk 68 of 112 extracted 14 Ent + 0 Rel chunk-4ea618890f71d27e2096399bad6cd1de
# INFO:  == LLM cache == saving: default:extract:0b47dc74d1138a71b9ddc50003d741f8
# WARNING: chunk-7faebdcc1f2cb6de3a4fa53deac04609: Complete delimiter can not be found in extraction result
# INFO: Chunk 69 of 112 extracted 16 Ent + 0 Rel chunk-7faebdcc1f2cb6de3a4fa53deac04609
# INFO:  == LLM cache == saving: default:extract:f3e84f5443fe5547129b1e62c4153b10
# WARNING: chunk-6a07cef9c51cb895b8c2986a79ff79f7: Complete delimiter can not be found in extraction result
# WARNING: chunk-6a07cef9c51cb895b8c2986a79ff79f7: LLM output format error; found 3/5 fields on REALTION `Chin-Hsi Lin`~`Chun Lai<`
# INFO: Chunk 70 of 112 extracted 10 Ent + 2 Rel chunk-6a07cef9c51cb895b8c2986a79ff79f7
# INFO:  == LLM cache == saving: default:extract:a4a6730bc1deae68d130d3fff22ba126
# WARNING: chunk-54891ff0777429ed4fab0977b347f10f: Complete delimiter can not be found in extraction result
# INFO: Chunk 71 of 112 extracted 13 Ent + 0 Rel chunk-54891ff0777429ed4fab0977b347f10f
# INFO:  == LLM cache == saving: default:extract:2161831704cea94bf5df87c3072a5120
# WARNING: chunk-554ddca1a28cb2a3fe38aa4c0a715119: Complete delimiter can not be found in extraction result
# WARNING: chunk-554ddca1a28cb2a3fe38aa4c0a715119: LLM output format error; found 2/5 fields on REALTION `AI-Blended Instruction`~`N/A`
# INFO: Chunk 72 of 112 extracted 10 Ent + 3 Rel chunk-554ddca1a28cb2a3fe38aa4c0a715119
# INFO:  == LLM cache == saving: default:extract:16155d6e2a10e73f637073cab5f661a5
# WARNING: chunk-e034fd7b825b1c973f70f3d59bf88116: Complete delimiter can not be found in extraction result
# INFO: Chunk 73 of 112 extracted 14 Ent + 0 Rel chunk-e034fd7b825b1c973f70f3d59bf88116
# INFO:  == LLM cache == saving: default:extract:5c56fd86179b4569a0fe18c671dd3a83
# WARNING: chunk-17fda6816ac0385fc6946da1b18b9189: Complete delimiter can not be found in extraction result
# INFO: Chunk 74 of 112 extracted 14 Ent + 0 Rel chunk-17fda6816ac0385fc6946da1b18b9189
# INFO:  == LLM cache == saving: default:extract:db4b0556651bfe524062f060a55d8968
# WARNING: chunk-f1f4ab9969c19c993c5c6befdb5989e7: Complete delimiter can not be found in extraction result
# INFO: Chunk 75 of 112 extracted 15 Ent + 0 Rel chunk-f1f4ab9969c19c993c5c6befdb5989e7
# INFO:  == LLM cache == saving: default:extract:7162c51c45474043c91d55a754373ec5
# WARNING: chunk-9903565cb9cea128ff25f18a1edba9c2: Complete delimiter can not be found in extraction result
# WARNING: chunk-9903565cb9cea128ff25f18a1edba9c2: LLM output format error; found 2/4 feilds on ENTITY `Qualitative Analysis<|#` @ `N/A`
# INFO: Chunk 76 of 112 extracted 11 Ent + 0 Rel chunk-9903565cb9cea128ff25f18a1edba9c2
# INFO:  == LLM cache == saving: default:extract:d67bda50f48644506c7df6212ad48e1c
# WARNING: chunk-e103285f76d81ce47903371c007f850c: Complete delimiter can not be found in extraction result
# INFO: Chunk 77 of 112 extracted 13 Ent + 0 Rel chunk-e103285f76d81ce47903371c007f850c
# INFO:  == LLM cache == saving: default:extract:432bb93ce5fa47df3a78ac211aa7e665
# WARNING: chunk-77cbe3c7083f04ea48da857f7d81eb12: Complete delimiter can not be found in extraction result
# INFO: Chunk 78 of 112 extracted 8 Ent + 2 Rel chunk-77cbe3c7083f04ea48da857f7d81eb12
# INFO:  == LLM cache == saving: default:extract:b8d8ed8b8fb80d04668c7fdfe0f4f863
# WARNING: chunk-4846518ebcf56053644e769e47467f9c: Complete delimiter can not be found in extraction result
# WARNING: chunk-4846518ebcf56053644e769e47467f9c: LLM output format error; found 2/4 feilds on ENTITY `Structural Relationship Between L2 Learning Motivation and` @ `N/A`
# WARNING: chunk-4846518ebcf56053644e769e47467f9c: LLM output format error; found 3/4 feilds on ENTITY `content` @ `This title represents an exploratory study examining motivational and resilience factors affecting EFL learners' behavior and proficiency.`
# INFO: Chunk 79 of 112 extracted 13 Ent + 0 Rel chunk-4846518ebcf56053644e769e47467f9c
# INFO:  == LLM cache == saving: default:extract:92f270c78f953f6d9c4f2dd408072c09
# WARNING: chunk-000efb8a747897035373e9690dc09210: Complete delimiter can not be found in extraction result
# INFO: Chunk 80 of 112 extracted 13 Ent + 0 Rel chunk-000efb8a747897035373e9690dc09210
# INFO:  == LLM cache == saving: default:extract:24731fba7ee2f92d625179d34ae258a3
# WARNING: chunk-a904c63aa0f11f323da3178f9db515d9: Complete delimiter can not be found in extraction result
# WARNING: chunk-a904c63aa0f11f323da3178f9db515d9: LLM output format error; found 3/4 feilds on ENTITY `Artificial Intelligence` @ `Concept<`
# INFO: Chunk 81 of 112 extracted 14 Ent + 0 Rel chunk-a904c63aa0f11f323da3178f9db515d9
# INFO:  == LLM cache == saving: default:extract:3102d319e9a78151e25641e99b95d3ab
# WARNING: chunk-fcc7769836b5b4d78f4c17eeff4f28f1: Complete delimiter can not be found in extraction result
# INFO: Chunk 82 of 112 extracted 13 Ent + 0 Rel chunk-fcc7769836b5b4d78f4c17eeff4f28f1
# INFO:  == LLM cache == saving: default:extract:c2fa514ab651b10fa6343880331778e3
# WARNING: chunk-db63348b63d6075ed8eb70af3bfd41c3: Complete delimiter can not be found in extraction result
# INFO: Chunk 83 of 112 extracted 7 Ent + 5 Rel chunk-db63348b63d6075ed8eb70af3bfd41c3
# INFO:  == LLM cache == saving: default:extract:8fd8b7104a838534b7fae651076e6fba
# WARNING: chunk-bc84a71979b6c36f5995ffdd3eb0cc48: Complete delimiter can not be found in extraction result
# INFO: Chunk 84 of 112 extracted 13 Ent + 0 Rel chunk-bc84a71979b6c36f5995ffdd3eb0cc48
# INFO:  == LLM cache == saving: default:extract:34c014fa5216857fd97e11ca80f8136f
# WARNING: chunk-2ae4146776ea67b4a6c7915a304ad710: Complete delimiter can not be found in extraction result
# INFO: Chunk 85 of 112 extracted 14 Ent + 0 Rel chunk-2ae4146776ea67b4a6c7915a304ad710
# INFO:  == LLM cache == saving: default:extract:152c808c140b53587e25f623dc9189b2
# WARNING: chunk-21ee5fa6e3266b1a0627a2e4348f8e22: Complete delimiter can not be found in extraction result
# INFO: Chunk 86 of 112 extracted 12 Ent + 0 Rel chunk-21ee5fa6e3266b1a0627a2e4348f8e22
# INFO:  == LLM cache == saving: default:extract:6c2db3d3f8dd93473d19856027a85f8e
# WARNING: chunk-146ce4e08bffcabb3af32bf3cc20623b: Complete delimiter can not be found in extraction result
# INFO: Chunk 87 of 112 extracted 13 Ent + 0 Rel chunk-146ce4e08bffcabb3af32bf3cc20623b
# INFO:  == LLM cache == saving: default:extract:140302db181e32b239b4332a18a33775
# WARNING: chunk-90a175b0be92e7b9df6331928d3b3967: Complete delimiter can not be found in extraction result
# INFO: Chunk 88 of 112 extracted 16 Ent + 0 Rel chunk-90a175b0be92e7b9df6331928d3b3967
# INFO:  == LLM cache == saving: default:extract:887a8f4ef9f98818597af7e08ab3e25a
# WARNING: chunk-879f6050ed786cf18590d0cc6e95e254: Complete delimiter can not be found in extraction result
# WARNING: chunk-879f6050ed786cf18590d0cc6e95e254: LLM output format error; found 2/4 feilds on ENTITY `Treatment Group` @ `N/A`
# INFO: Chunk 89 of 112 extracted 13 Ent + 0 Rel chunk-879f6050ed786cf18590d0cc6e95e254
# INFO:  == LLM cache == saving: default:extract:b96055808883a1f664c430f41cd80582
# WARNING: chunk-222f4ad00c9ec18d46ed758fa9a9038d: Complete delimiter can not be found in extraction result
# WARNING: chunk-222f4ad00c9ec18d46ed758fa9a9038d: LLM output format error; found 2/4 feilds on ENTITY `11/9/2025` @ `N/A`
# INFO: Chunk 90 of 112 extracted 8 Ent + 0 Rel chunk-222f4ad00c9ec18d46ed758fa9a9038d
# INFO:  == LLM cache == saving: default:extract:776c3e2c1e55839c22aacb3bab12df97
# WARNING: chunk-77fd2b6254c4f2105038069778bcb5ae: Complete delimiter can not be found in extraction result
# INFO: Chunk 91 of 112 extracted 14 Ent + 0 Rel chunk-77fd2b6254c4f2105038069778bcb5ae
# INFO:  == LLM cache == saving: default:extract:a4bc3bbae108c624affec66249b4ad79
# WARNING: chunk-7439a92d3d8b12ba841826d84e7efccf: Complete delimiter can not be found in extraction result
# INFO: Chunk 92 of 112 extracted 15 Ent + 0 Rel chunk-7439a92d3d8b12ba841826d84e7efccf
# INFO:  == LLM cache == saving: default:extract:56e4920aaf7fb56211b4cb20c48c44cd
# WARNING: chunk-7ac880ad98e944d01e7ee58b611ebb7c: Complete delimiter can not be found in extraction result
# INFO: Chunk 93 of 112 extracted 13 Ent + 0 Rel chunk-7ac880ad98e944d01e7ee58b611ebb7c
# INFO:  == LLM cache == saving: default:extract:59c966eba112fc12d6fc4a75a4c2a93a
# WARNING: chunk-ab5b80781d717853250bdb6be4bff74f: Complete delimiter can not be found in extraction result
# INFO: Chunk 94 of 112 extracted 15 Ent + 0 Rel chunk-ab5b80781d717853250bdb6be4bff74f
# INFO:  == LLM cache == saving: default:extract:2a464919d202193a995699c43faffd32
# WARNING: chunk-7321411794b81f73989218607cf84a44: Complete delimiter can not be found in extraction result
# WARNING: chunk-7321411794b81f73989218607cf84a44: LLM output format error; found 2/5 fields on REALTION `H`~`N/A`
# INFO: Chunk 95 of 112 extracted 10 Ent + 4 Rel chunk-7321411794b81f73989218607cf84a44
# INFO:  == LLM cache == saving: default:extract:630cce847def8441991a8f8337743d5b
# WARNING: chunk-146fcb107deaf04160140c2b869c2a4b: Complete delimiter can not be found in extraction result
# INFO: Chunk 96 of 112 extracted 14 Ent + 0 Rel chunk-146fcb107deaf04160140c2b869c2a4b
# INFO:  == LLM cache == saving: default:extract:b4718a01279469727d004aafb7cebc92
# WARNING: chunk-4574333b632d9e66a063470a23c0a5fa: Complete delimiter can not be found in extraction result
# WARNING: chunk-4574333b632d9e66a063470a23c0a5fa: LLM output format error; found 2/4 feilds on ENTITY `Education and Information Technologies<` @ `N/A`
# INFO: Chunk 97 of 112 extracted 16 Ent + 0 Rel chunk-4574333b632d9e66a063470a23c0a5fa
# INFO:  == LLM cache == saving: default:extract:cedad2b49605877fde15eb2b434e530c
# WARNING: chunk-609ecf3cdd5ef459296170c35e6be4b7: Complete delimiter can not be found in extraction result
# WARNING: chunk-609ecf3cdd5ef459296170c35e6be4b7: LLM output format error; found 2/4 feilds on ENTITY `English Anxiety` @ `N/A`
# INFO: Chunk 98 of 112 extracted 12 Ent + 0 Rel chunk-609ecf3cdd5ef459296170c35e6be4b7
# INFO:  == LLM cache == saving: default:extract:9202bf3f619939ccbea8689b58b2d6f1
# WARNING: chunk-34b0662ce7d3cb8852afe9d4794bdbd0: Complete delimiter can not be found in extraction result
# INFO: Chunk 99 of 112 extracted 6 Ent + 0 Rel chunk-34b0662ce7d3cb8852afe9d4794bdbd0
# INFO:  == LLM cache == saving: default:extract:cafa0452d821503a052c0feee7d17223
# WARNING: chunk-6417dce4865188dc38b26d1d9e9773f7: Complete delimiter can not be found in extraction result
# WARNING: chunk-6417dce4865188dc38b26d1d9e9773f7: LLM output format error; found 4/5 fields on REALTION `Jianling Zhan`~`Yuan Yao`
# INFO: Chunk 100 of 112 extracted 13 Ent + 0 Rel chunk-6417dce4865188dc38b26d1d9e9773f7
# INFO:  == LLM cache == saving: default:extract:436dd65cc235a6b5c069cfbd4daff4ac
# WARNING: chunk-9fddb74b07f84ce562fd046c8f31a823: Complete delimiter can not be found in extraction result
# INFO: Chunk 101 of 112 extracted 15 Ent + 0 Rel chunk-9fddb74b07f84ce562fd046c8f31a823
# INFO:  == LLM cache == saving: default:extract:9d701ba7a903a5c5295bae6a75411b26
# WARNING: chunk-8789302cbaac9ca8357729c602ccb70b: Complete delimiter can not be found in extraction result
# INFO: Chunk 102 of 112 extracted 14 Ent + 0 Rel chunk-8789302cbaac9ca8357729c602ccb70b
# INFO:  == LLM cache == saving: default:extract:d34bd8ff59ecbf8417696a892d9b44b0
# WARNING: chunk-f664d334e2a5e3f4a4ab0054c344ee3f: Complete delimiter can not be found in extraction result
# WARNING: chunk-f664d334e2a5e3f4a4ab0054c344ee3f: LLM output format error; found 3/5 fields on REALTION `GenAI`~`Academic Writing<`
# INFO: Chunk 103 of 112 extracted 13 Ent + 0 Rel chunk-f664d334e2a5e3f4a4ab0054c344ee3f
# INFO:  == LLM cache == saving: default:extract:71862aabf7b30b0fa47bfc3b6b52ae94
# WARNING: chunk-16ee23a11a101c789e9d45e98d3d7471: Complete delimiter can not be found in extraction result
# WARNING: chunk-16ee23a11a101c789e9d45e98d3d7471: LLM output format error; found 3/4 feilds on ENTITY `Intrinsic Motivation` @ `concept`
# INFO: Chunk 104 of 112 extracted 12 Ent + 0 Rel chunk-16ee23a11a101c789e9d45e98d3d7471
# INFO:  == LLM cache == saving: default:extract:afe2f80db1085ac0e9daa08cfdcfed39
# WARNING: chunk-54ea7bd070d0aa48bfb36af206578bce: Complete delimiter can not be found in extraction result
# WARNING: chunk-54ea7bd070d0aa48bfb36af206578bce: LLM output format error; found 2/4 feilds on ENTITY `Control` @ `N/A`
# INFO: Chunk 105 of 112 extracted 12 Ent + 0 Rel chunk-54ea7bd070d0aa48bfb36af206578bce
# INFO:  == LLM cache == saving: default:extract:ade1a18003c996b2fcfbcf4b11ba0c9e
# WARNING: chunk-5d48977af9b0e7d251ea81cb0d487351: Complete delimiter can not be found in extraction result
# WARNING: chunk-5d48977af9b0e7d251ea81cb0d487351: LLM output format error; found 2/4 feilds on ENTITY `Writing Motivation<` @ `N/A`
# INFO: Chunk 106 of 112 extracted 14 Ent + 0 Rel chunk-5d48977af9b0e7d251ea81cb0d487351
# INFO:  == LLM cache == saving: default:extract:5c4d2448a864437aad226e6f114867d9
# WARNING: chunk-1cfe70580e9428291d988632eb1da1da: Complete delimiter can not be found in extraction result
# WARNING: chunk-1cfe70580e9428291d988632eb1da1da: LLM output format error; found 2/4 feilds on ENTITY `Three Educational` @ `N/A`
# INFO: Chunk 107 of 112 extracted 12 Ent + 0 Rel chunk-1cfe70580e9428291d988632eb1da1da
# INFO:  == LLM cache == saving: default:extract:220a74445ba6260fdfbf4c6e4e5936fe
# WARNING: chunk-1d977235913375078bbe32cb2b8bf168: Complete delimiter can not be found in extraction result
# WARNING: chunk-1d977235913375078bbe32cb2b8bf168: LLM output format error; found 4/5 fields on REALTION `Vividness of the Future Self`~`delinquency prevention, cognitive intervention`
# INFO: Chunk 108 of 112 extracted 7 Ent + 3 Rel chunk-1d977235913375078bbe32cb2b8bf168
# INFO:  == LLM cache == saving: default:extract:403c1317eb50d892e223b11742cb80d6
# WARNING: chunk-910834b877bc22af2ac3ad451888a94b: Complete delimiter can not be found in extraction result
# WARNING: chunk-910834b877bc22af2ac3ad451888a94b: LLM output format error; found 3/4 feilds on ENTITY `Acta Psychologica` @ `publication`
# INFO: Chunk 109 of 112 extracted 13 Ent + 0 Rel chunk-910834b877bc22af2ac3ad451888a94b
# INFO:  == LLM cache == saving: default:extract:9ed68ed43bb430dce72e1271fc61f3e1
# WARNING: chunk-2197adb18f8ba6202c6a4562c6809fbf: Complete delimiter can not be found in extraction result
# INFO: Chunk 110 of 112 extracted 17 Ent + 0 Rel chunk-2197adb18f8ba6202c6a4562c6809fbf
# INFO:  == LLM cache == saving: default:extract:67501dc5aa479fb0c3a5c9280fdd5be0
# WARNING: chunk-92abb7ea9dad854322d76ea04c1027b8: Complete delimiter can not be found in extraction result
# WARNING: chunk-92abb7ea9dad854322d76ea04c1027b8: LLM output format error; found 2/4 feilds on ENTITY `Vision-Inspired Instruction` @ `N/A`
# INFO: Chunk 111 of 112 extracted 13 Ent + 0 Rel chunk-92abb7ea9dad854322d76ea04c1027b8
# INFO:  == LLM cache == saving: default:extract:71ff6e8f3f570fd86467aa8103f02fd5
# INFO: Chunk 112 of 112 extracted 5 Ent + 0 Rel chunk-8fa0a25c0445e33a03ae0e40a08ce5f5
# INFO: Merging stage 1/1: unknown_source
# INFO: Phase 1: Processing 1052 entities from doc-14988456e477bf51ec3488b3f381162d (async: 2)
# INFO:  == LLM cache == saving: default:summary:05138fc9fe98cee330ac715c67a7dd3a
# INFO: LLMmrg: `Artificial Intelligence` | 0+8
# INFO:  == LLM cache == saving: default:summary:e8533341bc525ca885aa68d4477e5fe6
# INFO: LLMmrg: `Control Group` | 0+12
# INFO:  == LLM cache == saving: default:summary:f51f3a40b0f89db2d1347c00e097f12b
# INFO: LLMmrg: `Ideal L2 Writing Self` | 0+9
# INFO:  == LLM cache == saving: default:summary:4d3bfda5c9ec3d659daf68257aa69f4c
# INFO: LLMmrg: `ChatGPT` | 0+36
# INFO:  == LLM cache == saving: default:summary:ca59a9964137b6555c110aba4c2d44dd
# INFO: LLMmrg: `Ideal L2 Self` | 0+11
# INFO:  == LLM cache == saving: default:summary:f787fcdcf18f15c4e65eb34f13a18748
# INFO: LLMmrg: `Self-Efficacy` | 0+8 (dd 1)
# INFO:  == LLM cache == saving: default:summary:c40683ecfeb222cb4ce2084e684e1aa6
# INFO: LLMmrg: `L2 Motivational Self System` | 0+8
# INFO: Phase 2: Processing 51 relations from doc-14988456e477bf51ec3488b3f381162d (async: 2)
# INFO: Chunks appended from relation: `Ideal L2 Writing Self`
# INFO: Chunks appended from relation: `Education and Information Technologies`
# INFO: Phase 3: Updating final 1055(1052+3) entities and  51 relations from doc-14988456e477bf51ec3488b3f381162d
# INFO: Completed merging: 1052 entities, 3 extra entities, 51 relations
# INFO: [_] Writing graph with 1055 nodes, 51 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/1: unknown_source
# INFO: Enqueued document processing pipeline stopped
#   ✅ Indexed successfully
#
# 🎉 Indexing Complete! Processed 1/1 documents
# 💾 Knowledge graph saved to: /content/drive/MyDrive/LightRAG_Storage

# %%
# ============================================================
# Cell 5: Query Interface
# ============================================================

# @title 🔎 Research Query Interface
question = "What do you know about Ideal L2 writing self?" # @param {type:"string"}
search_mode = "local" # @param ["global", "local", "hybrid", "naive"]

# Search mode guide:
# - global: Best for themes, summaries, big picture
# - local: Best for specific facts, detailed info
# - hybrid: Combines both (recommended)
# - naive: Simple vector search

param = QueryParam(mode=search_mode)

print(f"🧠 Querying: '{question}'")
print(f"🔍 Mode: {search_mode}")
print("⏳ Thinking...\n")

result = await rag.aquery(question, param=param)

print("="*80)
print("📝 RESEARCH REPORT:")
print("="*80)
print(result)
print("="*80)
# Out:
# 🧠 Querying: 'What do you know about Ideal L2 writing self?'
# 🔍 Mode: local
# ⏳ Thinking...
# INFO:  == LLM cache == saving: local:keywords:57d699c230a993dd4ef0af2fc2e962be
# INFO: Query nodes: Ideal L2, writing, self (top_k:40, cosine:0.2)
# INFO: Local query: 40 entites, 4 relations
# INFO: Raw search results: 40 entities, 4 relations, 0 vector chunks
# INFO: After truncation: 40 entities, 4 relations
# INFO: Selecting 42 from 42 entity-related chunks by vector similarity
# INFO: Find no additional relations-related chunks from 4 relations
# INFO: Round-robin merged chunks: 42 -> 42 (deduplicated 0)
# WARNING: Rerank is enabled but no rerank model is configured. Please set up a rerank model or set enable_rerank=False in query parameters.
# INFO: Final context: 40 entities, 4 relations, 20 chunks
# INFO: Final chunks S+F/O: E6/1 E3/2 E1/3 E1/4 E3/5 E2/6 E2/7 E2/8 E2/9 E2/10 E4/11 E2/12 E2/13 E3/14 E1/15 E2/16 E1/17 E1/18 E1/19 E2/20
# ERROR: LLM func: Error in decorated function for task 139329075923264_9336.609689835: CUDA out of memory. Tried to allocate 1.75 GiB. GPU 0 has a total capacity of 14.74 GiB of which 856.12 MiB is free. Process 15755 has 13.90 GiB memory in use. Of the allocated memory 12.90 GiB is allocated by PyTorch, and 850.96 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR: Query failed: CUDA out of memory. Tried to allocate 1.75 GiB. GPU 0 has a total capacity of 14.74 GiB of which 856.12 MiB is free. Process 15755 has 13.90 GiB memory in use. Of the allocated memory 12.90 GiB is allocated by PyTorch, and 850.96 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ================================================================================
# 📝 RESEARCH REPORT:
# ================================================================================
# None
# ================================================================================
